# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Experiment 1

# %%
f_list = ["./data/eval_student_reform-end-to-end_l50_j5_n10000.csv", "./data/eval_student_exp1_l100_j5_n10000.csv", "./data/eval_student_exp1_l150_j5_n10000.csv", "./data/eval_student_exp1_l200_j5_n10000.csv"]
nn_mse = []
bnb_mse = []
for fname in f_list:
    eval = pd.read_csv(fname)
    nn_mean = eval.NN_mean.mean()
    nn_mse.append(nn_mean)
    bnb_mean = eval.BnB_mean.mean()
    bnb_mse.append(bnb_mean)
    print(f"NN Mean = {nn_mean:.3e}")
    print(f"Bnb Mean = {bnb_mean:.3e}")
length_of_trial_vec = [50, 100, 150, 200]
plt.plot(length_of_trial_vec, nn_mse, "-ob",label="NN MSE")
plt.plot(length_of_trial_vec, bnb_mse, "--sr",label="BnB MSE")
plt.xlabel("Length of trial (timeslots)")
plt.ylabel("Average MSE (normalized)")
plt.legend()
plt.grid()
plt.title(f"Varying the length of the BnB trial")
plt.savefig(f"./plots/exp1.png")
# Out:
# NN Mean = 6.236e-03
# Bnb Mean = 1.268e-02
# NN Mean = 1.883e-03
# Bnb Mean = 4.255e-03
# NN Mean = 1.285e-03
# Bnb Mean = 2.213e-03
# NN Mean = 5.241e-04
# Bnb Mean = 1.451e-03

# %% [markdown]
# ## Experiment 2

# %%
f_list = ["./data/eval_student_reform-end-to-end_l50_j5_n10000.csv", "./data/eval_student_exp1_l50_j10_n10000.csv", "./data/eval_student_exp1_l50_j20_n10000.csv", "./data/eval_student_exp1_l50_j50_n10000.csv"]
nn_mse = []
bnb_mse = []
for fname in f_list:
    eval = pd.read_csv(fname)
    nn_mean = eval.NN_mean.mean()
    nn_mse.append(nn_mean)
    bnb_mean = eval.BnB_mean.mean()
    bnb_mse.append(bnb_mean)
    print(f"NN Mean = {nn_mean:.3e}")
    print(f"Bnb Mean = {bnb_mean:.3e}")
jumps_vec = [5, 10, 20, 50]
bnb_mse=np.array(bnb_mse)
nn_mse=np.array(nn_mse)
plt.plot(jumps_vec, nn_mse, "-ob",label="NN MSE")
plt.plot(jumps_vec, bnb_mse, "--sr",label="BnB MSE")
# plt.plot(jumps_vec, bnb_mse-nn_mse, "-ok")
plt.xlabel("jumps")
plt.ylabel("Average MSE")
plt.title(f"Varying the number of jumps in the TPM")
plt.legend()
plt.grid()
plt.savefig(f"./plots/exp2.png")
# Out:
# NN Mean = 6.236e-03
# Bnb Mean = 1.268e-02
# NN Mean = 3.954e-03
# Bnb Mean = 1.135e-02
# NN Mean = 2.296e-03
# Bnb Mean = 1.055e-02
# NN Mean = 2.116e-03
# Bnb Mean = 1.019e-02

# %% [markdown]
# ## Experiment 3 : same model, different jumps

# %%
f_list = ["./data/eval_student_jumps_try_j5_og_j20.csv","./data/eval_student_jumps_try_j10_og_j20.csv","./data/eval_student_exp1_l50_j20_n10000.csv", "./data/eval_student_jumps_try_j50_og_j20.csv", "./data/eval_student_jumps_try_j100_og_j20.csv" ]
nn_mse = []
bnb_mse = []
for fname in f_list:
    eval = pd.read_csv(fname)
    nn_mean = eval.NN_mean.mean()
    nn_mse.append(nn_mean)
    bnb_mean = eval.BnB_mean.mean()
    bnb_mse.append(bnb_mean)
    print(f"NN Mean = {nn_mean:.3e}")
    print(f"Bnb Mean = {bnb_mean:.3e}")
jumps_vec = [5, 10, 20, 50, 100]
bnb_mse=np.array(bnb_mse)
nn_mse=np.array(nn_mse)
plt.plot(jumps_vec, nn_mse, "-ob",label="NN MSE")
plt.plot(jumps_vec, bnb_mse, "--sr",label="BnB MSE")
# plt.plot(jumps_vec, bnb_mse-nn_mse, "-ok")
plt.xlabel("jumps")
plt.ylabel("Average MSE")
plt.title(f"Testing same model (trained on 20 jumps) for different DTMCs")
plt.legend()
plt.grid()
plt.savefig(f"./plots/exp3.png")
# Out:
# NN Mean = 2.323e-03
# Bnb Mean = 1.230e-02
# NN Mean = 2.130e-03
# Bnb Mean = 1.102e-02
# NN Mean = 2.296e-03
# Bnb Mean = 1.055e-02
# NN Mean = 2.020e-03
# Bnb Mean = 9.112e-03

# %% [markdown]
# ## Experiment 4 : changing $\alpha$

# %%
alpha_df = pd.read_csv("varying_alpha.csv")
plt.figure(0)
plt.plot(alpha_df['alpha'], alpha_df['test'], '-ok')
plt.grid()
plt.xlabel(r"Mixing ratio for distillation ($\alpha$)")
plt.ylabel("Test MSE (normalized)")
plt.title(r"Test loss with $\alpha$")
plt.savefig("./plots/test_alpha.png")

plt.figure(1)
plt.plot(alpha_df['alpha'], alpha_df['training'], '-ok')
plt.grid()
plt.xlabel(r"Mixing ratio for distillation ($\alpha$)")
plt.ylabel("Training MSE (normalized)")
plt.title(r"Training loss with $\alpha$")
plt.savefig("./plots/training_alpha.png")
